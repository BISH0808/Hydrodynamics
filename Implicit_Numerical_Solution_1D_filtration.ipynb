# %% [markdown]
# # Неявное решение уравнения фильтрации однофазной жидкости в одномерном пласте

# %% [markdown]
# **Линейная фильтрация жидкости в пласте**

# %% [markdown]
# Представим горизонтальный пласт в котором изначально давление в любой точке 𝑃_𝑜. В нулевой момент времени давление на левой грани меняется на 𝑃_Л, а на правой меняется на 𝑃_П. Система представлена ниже.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600" align="left"/>
# </div>

# %% [markdown]
# **Явная запись решения ДУ**

# %% [markdown]
# Уравнение притока:

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500" align="left"/>
# </div>

# %% [markdown]
# Т.к. вывод левой части производился при постоянном времени, можно переписать эту часть на момент времени 𝑡+∆𝑡:

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500" align="left"/>
# </div>

# %% [markdown]
# **Граничные условия**

# %% [markdown]
# Граничные условия постоянного давления:

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500" align="left"/>
# </div>

# %% [markdown]
# Граничные условия постоянного расхода:

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500" align="left"/>
# </div>

# %% [markdown]
# **Неявная запись решения ДУ**

# %% [markdown]
# Теперь возможно записать набор из N уравнений с N количеством неизвестных, которые должны быть решены одновременно (СЛАУ). Для простоты, данный набор уравнений может быть записан в данной форме:

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500" align="left"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200" align="left"/>
# </div>

# %% [markdown]
# **Коэффициенты СЛАУ:**

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="350" align="left"/>
# </div>

# %% [markdown]
# **Коэффициенты для левого граничного условия постоянного давления:**

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200" align="left"/>
# </div>

# %% [markdown]
# **Коэффициенты для правого граничного условия постоянного давления:**

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="250" align="left"/>
# </div>

# %% [markdown]
# **Коэффициенты для левого граничного условия постоянного расхода**

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="220" align="left"/>
# </div>

# %% [markdown]
# **Коэффициенты для правого граничного условия постоянного расхода:**

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200" align="left"/>
# </div>

# %% [markdown]
# **Запись неявного решения в матричном виде**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Условия задачи:**

# %% [markdown]
# Рассчитать распределение давления в одномерном пласте используя неявный метод конечноразностного решения на 2 временных шага.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# **НУ – начальное условие; ЛГУ – левое граничное условие; ПГУ – правое граничное условие.**

# %% [markdown]
# # Дополнительное задание

# %% [markdown]
# Рассчитать распределение давления нефти в двухмерной модели пласта используя неявный метод конечноразностного решения на 5 временных шагов.

# %% [markdown]
# **Нумерация ячеек модели**

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200" align="left"/>
# </div>

# %% [markdown]
# **Распределение проницаемости, мД**

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200" align="left"/>
# </div>

# %% [markdown]
# **Таблица 1. Свойства пласта и нефти**

# %% [markdown]
# <div>
# <img src="attachment:image-2.png" width="600" align="left"/>
# </div>

# %% [markdown]
# Граничные условия на границе залежи – отсутствие перетока

# %% [markdown]
# **Таблица 2. Начальные и граничные условия**

# %% [markdown]
# <div>
# <img src="attachment:image-2.png" width="600" align="left"/>
# </div>
