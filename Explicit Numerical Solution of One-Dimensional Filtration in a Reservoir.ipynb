# %% [markdown]
# ## РГЗ "Явное решение уравнения фильтрации однофазной жидкости в одномерном пласте"

# %% [markdown]
# **Линейная фильтрация жидкости в пласте**

# %% [markdown]
# Представим горизонтальный пласт в котором изначально давление в любой точке 𝑃_𝑜. В нулевой момент времени давление на левой грани меняется на 𝑃_Л, а на правой меняется на 𝑃_П. Система представлена ниже.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **ДУ в частных производных**

# %% [markdown]
# Дифференциальное уравнение в частных производных для линейной одномерной горизонтальной фильтрации жидкости, с учетом постоянной проницаемости а также вязкости и сжимаемости жидкости, имеет вид:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Численное решение ДУ в частных производных**

# %% [markdown]
# В общем случае аналитическое решение данного уравнения возможно получить, только с учетом упрощений связанных с геометрией пласта, его свойствами и свойствами вмещаемого флюида, а также с граничными условиями. Это существенно снижает применимость данного решения. Данные упрощения не подходят для решения многих задач, связанных с течением жидкостей в реальных залежах. Следовательно, необходимо решать данное уравнение в численном виде.

# %% [markdown]
# **Дискретизация**

# %% [markdown]
# Данное уравнение будет решено численно используя конечно-разностную аппроксимацию для двух дифференциальных составляющих:
# ![image.png](attachment:image.png)

# %% [markdown]
# Для начала пространство по оси X должно быть разделено на некоторое количество ячеек, а координата времени должна быть поделена на некоторые конечные временные интервалы (шаги). Затем, значение давления в каждой ячейке может быть определенно численно для каждого временного шага.  Для одномерного горизонтального порового пространства определена сетчатая система с количеством ячеек N. Длина каждой ячейки ∆𝑥.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Данную сетку называют блочно-центрированной. Каждой ячейке в сетке присвоен индекс i, который относится к центральной точке каждой ячейки и представляет усреднённое значение свойств для этой ячейки.

# %% [markdown]
# **Аппроксимация в рядах Тейлора**

# %% [markdown]
# Конечно-разностные уравнения записываются таким образом, чтобы можно было получить значения зависимых параметров по всей сеточной области.
# Уравнения в частных производных заменяют их конечно разностными эквивалентами. Получить конечно-разностные уравнения можно, используя метод разложения функции в ряд Тейлора в заданной точке и решая уравнения относительно искомой производной.
#
#
# Аппроксимация в рядах Тейлора функции 𝑓(𝑥+ℎ) выраженной в 𝑓(𝑥) и её производных f’(x) может быть записана как:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Аппроксимация дифференциальной составляющей пространства второго порядка**

# %% [markdown]
# При постоянном времени t можно записать уравнение давления при движении вперед и назад по оси Х в следующем виде:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Складывая эти два уравнения и решая для производной второго порядка получим:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Или, применяя индексацию для ячеек и обозначив верхним индексом временной интервал получим:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Аппроксимация дифференциальной составляющей времени**

# %% [markdown]
# В постоянной точке пространства x можно записать уравнение давления вперед по оси времени в следующем виде:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Решая уравнение относительно первой производной по времени, получим:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Или, применяя индексацию для ячеек:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Явная запись решения ДУ**

# %% [markdown]
# Используя аппроксимации полученные выше в первоначальное дифференциальное уравнение притока получим:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Для удобства величины погрешности опущены в данном уравнении. Однако, важно помнить, что погрешность в данном численном решении уравнения притока соответственно пропорциональна ∆𝑡 и ∆𝑥^2.
